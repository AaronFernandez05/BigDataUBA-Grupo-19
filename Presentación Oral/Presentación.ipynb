# %%
#pip install xlrd (Para poder acceder a la base de datos del 2015)

# %%
import pandas as pd

base_2015 = pd.ExcelFile("C:/Users/CRIS/Documents/Big Data/Big Data Grupo 19/Presentación/YPF_Base2015.xls")
base_2024 = pd.ExcelFile("C:/Users/CRIS/Documents/Big Data/Big Data Grupo 19/Presentación/YPF_Base2024.xlsx")

b2015 = base_2015.sheet_names
b2024 = base_2024.sheet_names

balance2015 = pd.read_excel("C:/Users/CRIS/Documents/Big Data/Big Data Grupo 19/Presentación/YPF_Base2015.xls", sheet_name=b2015[1])
balance2024 = pd.read_excel("C:/Users/CRIS/Documents/Big Data/Big Data Grupo 19/Presentación/YPF_Base2024.xlsx", sheet_name=b2024[12])
balance_2015 = balance2015.rename(columns={
    "Unnamed: 1": "Balance",
    "Unnamed: 3": 2015
})
balance_2024 = balance2024.rename(columns={
    "Unnamed: 1": "Balance",
    "Unnamed: 2": 2024
})
