# %%
#pip install xlrd (Para poder acceder a la base de datos del 2015)

# %%
import pandas as pd

base_2015 = pd.read_excel("C:/Users/CRIS/Documents/Big Data/Big Data Grupo 19/Presentación/YPF_Base2015.xls")
base_2024 = pd.read_excel("C:/Users/CRIS/Documents/Big Data/Big Data Grupo 19/Presentación/YPF_Base2024.xlsx")
