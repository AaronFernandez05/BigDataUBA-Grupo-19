# %%
#Datos 2015

# %%
import pandas as pd

base_2015 = pd.ExcelFile("C:/Users/roman/Downloads/YPF_Base2015.xls")

b2015 = base_2015.sheet_names


balance2015 = pd.read_excel("C:/Users/roman/Downloads/YPF_Base2015.xls", sheet_name=b2015[1])
balance_2015 = balance2015.rename(columns={
    "Unnamed: 1": "Balance",
    "Unnamed: 3": 2015
})

# %% [raw]
# print(b2015)

# %%
print(balance2015)
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0          NaN                                                NaN         NaN
# 1          NaN  BALANCES GENERALES (Cifras expresadas en millo...         NaN
# 2          NaN                              Activos no corrientes         NaN
# 3          NaN                                Activos intangibles         NaN
# 4          NaN                       Propiedades, planta y equipo         NaN
# 5          NaN           Inversiones en empresas y joint ventures         NaN
# 6          NaN             Activos mantenidos para su disposición         NaN
# 7          NaN              Activos por impuestos diferidos, neto         NaN
# 8          NaN                           Otras cuentas por cobrar         NaN
# 9          NaN                     Cuentas por cobrar comerciales         NaN
# 10         NaN                   Inversión en activos financieros         NaN
# ...

# %%
print(balance2024)
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                        Balance General Consolidado
# 1          NaN                                Cifras no auditadas
# 2          NaN                                Activo No Corriente
# 3          NaN                                Activos intangibles
# 4          NaN                       Propiedades, planta y equipo
# 5          NaN                         Activos por derecho de uso
# 6          NaN      Inversiones en asociadas y negocios conjuntos
# 7          NaN               Activos por impuesto diferido, netos
# 8          NaN                                     Otros créditos
# 9          NaN                                Créditos por ventas
# 10         NaN                 Inversiones en activos financieros
# 11         NaN                      Total del Activo No Corriente
# 12         NaN                                                NaN
# ...

# %%
df_2015 = pd.read_excel("C:/Users/roman/Downloads/YPF_Base2015.xls", skiprows=2)

# %%
print(df_2015)
# Out:
#     Unnamed: 0 (Amounts expressed in million of Argentine Pesos)   Unnamed: 2  \
# 0          NaN                                           Ingresos         NaN
# 1          NaN                                             Costos         NaN
# 2          NaN                                    Beneficio bruto         NaN
# 3          NaN                                   Gastos de Ventas         NaN
# 4          NaN                           Gastos de administración         NaN
# 5          NaN                              Gastos de exploración         NaN
# 6          NaN  (Reversión)/Deterioro del valor de propiedades...         NaN
# 7          NaN                 Otros resultados operativos, netos         NaN
# 8          NaN                                Ingresos operativos         NaN
# 9          NaN                                                NaN         NaN
# 10         NaN  Ingresos (pérdidas) por participación en empre...         NaN
# ...

# %%
df.dropna()  # Nan
df.dropna(how='all')  # eliminar filas vacías
# Out:
#                                                Cuenta  2015-12-31  2016-03-31
# 0                                            Ingresos    34702.00    40946.00
# 1                                              Costos   -26076.00   -32781.00
# 2                                     Beneficio bruto     8626.00     8165.00
# 3                                    Gastos de Ventas    -2592.00    -3034.00
# 4                            Gastos de administración    -1198.00    -1729.00
# 5                               Gastos de exploración     -191.00     -713.00
# 6   (Reversión)/Deterioro del valor de propiedades...        0.00    -2535.00
# 7                  Otros resultados operativos, netos     -176.00      756.00
# 8                                 Ingresos operativos     4469.00      910.00
# 9   Ingresos (pérdidas) por participación en empre...      -38.00      266.00
# 10                               Ingresos financieros     1774.00    21780.00
# ...
