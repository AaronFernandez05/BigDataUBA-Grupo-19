# %%
# Parte A para 2024.
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
respondieron_2024 = pd.read_csv("C:/Users/Administrator/Downloads/Big Data/TPs/TP2/respondieron_2024.csv")

# %%
# Variable dependiente
respondieron_2024["desocupado"] = (respondieron_2024["CAT_OCUP"] == 2).astype(int)

# %%
#Selección y renombrado de variables
variables_2024 = respondieron_2024[["CH04", "CH06", "NIVEL_ED", "REGION", "PONDERA", "desocupado"]].dropna()
variables_2024 = variables_2024.rename( columns={
    "CH04": "sexo",
    "CH06": "edad",
    "NIVEL_ED": "nivel_educativo",
    "REGION": "region",
    "PONDERA": "pondera",
   
})

# %%
# Convertir variables categóricas en dummies (ANTES de dividir)
df2024_dummies = pd.get_dummies(variables_2024, columns=["sexo", "nivel_educativo", "region"], drop_first=True)

# %%
# Separar variables dependientes e independientes
X = df2024_dummies.drop(columns="desocupado")
y = df2024_dummies["desocupado"]

# %%
# Agregar constante 
X["constante"] = 1

# %%
# División train/test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=444)

# %%
# Calcular diferencia de medias
mean_train = X_train.mean(numeric_only=True)
mean_test = X_test.mean(numeric_only=True)
diff_means = (mean_train - mean_test).to_frame(name="Diferencia de medias")

# %%
# Mostrar diferencias
print(diff_means)
# Out:
#                    Diferencia de medias
# edad                          -0.442100
# pondera                        8.220943
# sexo_Masculino                 0.009323
# nivel_educativo_2             -0.010557
# nivel_educativo_3             -0.020274
# nivel_educativo_4              0.014558
# nivel_educativo_5              0.008452
# nivel_educativo_6             -0.006954
# nivel_educativo_7              0.012737
# constante                      0.000000

# %%
# Reducimos decimlaes para que sea mas legible
diff_means = diff_means.round(3)
print(diff_means)
# Out:
#                    Diferencia de medias
# edad                             -0.442
# pondera                           8.221
# sexo_Masculino                    0.009
# nivel_educativo_2                -0.011
# nivel_educativo_3                -0.020
# nivel_educativo_4                 0.015
# nivel_educativo_5                 0.008
# nivel_educativo_6                -0.007
# nivel_educativo_7                 0.013
# constante                         0.000

# %%
# Parte A para 2004

# %%
respondieron_2004 = pd.read_csv("C:/Users/Administrator/Downloads/Big Data/TPs/TP2/respondieron_2004.csv")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4288\638692076.py:1: DtypeWarning: Columns (87,143,163,170,174) have mixed types. Specify dtype option on import or set low_memory=False.
#   respondieron_2004 = pd.read_csv("C:/Users/Administrator/Downloads/Big Data/TPs/TP2/respondieron_2004.csv")

# %%
# Variable dependiente
respondieron_2004["desocupado"] = (respondieron_2004["CAT_OCUP"] == "Desocupado").astype(int)

# %%
# Verificar y limpiar nombres de columnas
respondieron_2004.columns = respondieron_2004.columns.str.strip().str.upper()

# %%
# Verificar que 'CAT_OCUP' exista
print("Columnas disponibles:", respondieron_2004.columns.tolist())
# Out:
# Columnas disponibles: ['CODUSU', 'NRO_HOGAR', 'COMPONENTE', 'H15', 'ANO4', 'TRIMESTRE', 'REGION', 'MAS_500', 'AGLOMERADO', 'PONDERA', 'CH03', 'CH04', 'CH06', 'CH07', 'CH08', 'CH09', 'CH10', 'CH11', 'CH12', 'CH13', 'CH14', 'CH15', 'CH15_COD', 'CH16', 'CH16_COD', 'NIVEL_ED', 'ESTADO', 'CAT_OCUP', 'CAT_INAC', 'PP02C1', 'PP02C2', 'PP02C3', 'PP02C4', 'PP02C5', 'PP02C6', 'PP02C7', 'PP02C8', 'PP02E', 'PP02H', 'PP02I', 'PP03C', 'PP03D', 'PP3E_TOT', 'PP3F_TOT', 'PP03G', 'PP03H', 'PP03I', 'PP03J', 'INTENSI', 'PP04A', 'PP04B_COD', 'PP04B1', 'PP04B2', 'PP04B3_MES', 'PP04B3_ANO', 'PP04B3_DIA', 'PP04C', 'PP04C99', 'PP04D_COD', 'PP04G', 'PP05B2_MES', 'PP05B2_ANO', 'PP05B2_DIA', 'PP05C_1', 'PP05C_2', 'PP05C_3', 'PP05E', 'PP05F', 'PP05H', 'PP06A', 'PP06C', 'PP06D', 'PP06E', 'PP06H', 'PP07A', 'PP07C', 'PP07D', 'PP07E', 'PP07F1', 'PP07F2', 'PP07F3', 'PP07F4', 'PP07F5', 'PP07G1', 'PP07G2', 'PP07G3', 'PP07G4', 'PP07G_59', 'PP07H', 'PP07I', 'PP07J', 'PP07K', 'PP08D1', 'PP08D4', 'PP08F1', 'PP08F2', 'PP08J1', 'PP08J2', 'PP08J3', 'PP09A', 'PP09A_ESP', 'PP09B', 'PP09C', 'PP09C_ESP', 'PP10A', 'PP10C', 'PP10D', 'PP10E', 'PP11A', 'PP11B_COD', 'PP11B1', 'PP11B2_MES', 'PP11B2_ANO', 'PP11B2_DIA', 'PP11C', 'PP11C99', 'PP11D_COD', 'PP11G_ANO', 'PP11G_MES', 'PP11G_DIA', 'PP11L', 'PP11L1', 'PP11M', 'PP11N', 'PP11O', 'PP11P', 'PP11Q', 'PP11R', 'PP11S', 'PP11T', 'P21', 'DECOCUR', 'IDECOCUR', 'RDECOCUR', 'GDECOCUR', 'PDECOCUR', 'ADECOCUR', 'TOT_P12', 'P47T', 'DECINDR', 'IDECINDR', 'RDECINDR', 'GDECINDR', 'PDECINDR', 'ADECINDR', 'V2_M', 'V3_M', 'V4_M', 'V5_M', 'V8_M', 'V9_M', 'V10_M', 'V11_M', 'V12_M', 'V18_M', 'V19_AM', 'V21_M', 'T_VI', 'ITF', 'DECIFR', 'IDECIFR', 'RDECIFR', 'GDECIFR', 'PDECIFR', 'ADECIFR', 'IPCF', 'DECCFR', 'IDECCFR', 'RDECCFR', 'GDECCFR', 'PDECCFR', 'ADECCFR', 'PJ1_1', 'PJ2_1', 'PJ3_1', 'IDIMPP', 'AÑO', 'DESOCUPADO']

# %%
#Le damos valor numérico a la columna "CH_06"
respondieron_2004["CH06"] = respondieron_2004["CH06"].replace("Menos de 1 año", 0)
respondieron_2004["CH06"] = pd.to_numeric(respondieron_2004["CH06"])
respondieron_2004["CH06"] = respondieron_2004["CH06"].astype("int64")

# %%
# Selección y renombrado de variables
variable_2004 = respondieron_2004[["CH04", "CH06", "NIVEL_ED", "REGION", "PONDERA","DESOCUPADO"]].dropna()

# %%
variable_2004 = variable_2004.rename(columns={
    "CH04": "sexo",
    "CH06": "edad",
    "NIVEL_ED": "nivel_educativo",
    "REGION": "region",
    "PONDERA": "pondera",
    "DESOCUPADO": "desocupado",
    

})

# %%
# Convertir variables categóricas a dummies
df2004_dummies = pd.get_dummies(variable_2004, columns=["sexo", "nivel_educativo", "region"], drop_first=True)

# %%
# Separar variables dependientes e independientes
X = df2004_dummies.drop(columns="desocupado")
y = df2004_dummies["desocupado"]

# %%
# Agregar constante
X["constante"] = 1

# %%
# División train/test
X_entrenamiento, X_testeo, y_entrenamiento, y_testeo = train_test_split(X, y, test_size=0.3, random_state=444)

# %%
# Mostrar tipos de datos
print(X_entrenamiento.dtypes)
# Out:
# edad                                                                  int64
# pondera                                                             float64
# sexo_Masculino                                                         bool
# nivel_educativo_Primaria Incompleta (incluye educación especial)       bool
# nivel_educativo_Secundaria Completa                                    bool
# nivel_educativo_Secundaria Incompleta                                  bool
# nivel_educativo_Sin instrucción                                        bool
# nivel_educativo_Superior Universitaria Completa                        bool
# nivel_educativo_Superior Universitaria Incompleta                      bool
# constante                                                             int64
# dtype: object

# %%
# Calcular diferencia de medias
mean_entrenamiento = X_entrenamiento.mean(numeric_only=True)
mean_testeo = X_testeo.mean(numeric_only=True)
diferentes_means = (mean_entrenamiento - mean_testeo).to_frame(name="Diferencia de medias")

# %%
# Mostrar diferencias de medias
print(diferentes_means.round(3))
# Out:
#                                                     Diferencia de medias
# edad                                                              -0.316
# pondera                                                           -4.217
# sexo_Masculino                                                    -0.000
# nivel_educativo_Primaria Incompleta (incluye ed...                -0.021
# nivel_educativo_Secundaria Completa                                0.006
# nivel_educativo_Secundaria Incompleta                              0.021
# nivel_educativo_Sin instrucción                                   -0.012
# nivel_educativo_Superior Universitaria Completa                    0.006
# nivel_educativo_Superior Universitaria Incompleta                  0.010
# constante                                                          0.000

# %%
#Parte B
# Tabla 2: Estimación por regresión lineal de salarios usando la base de entrenamiento 
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
#Volvemos a darle nombre a las variables
respondieron_2024 = respondieron_2024.rename( columns={
    "CH04": "sexo",
    "CH06": "edad",
    "NIVEL_ED": "nivel_educativo",
    "REGION": "region",
    "PONDERA": "pondera",
   
})
respondieron_2004 = respondieron_2004.rename(columns={
    "CH04": "sexo",
    "CH06": "edad",
    "NIVEL_ED": "nivel_educativo",
    "REGION": "region",
    "PONDERA": "pondera",
    "DESOCUPADO": "desocupado",
    

})

# %%
# Cargamos el DataFrame limpio 
respondieron_2024 = respondieron_2024[["sexo", "edad", "nivel_educativo", "region", "pondera", "P47T", "PP3E_TOT", "PP3F_TOT"]]
respondieron_2004 = respondieron_2004[["sexo", "edad", "nivel_educativo", "region", "pondera", "P47T", "PP3E_TOT", "PP3F_TOT"]]

# %%
# Convertimos columnas si es necesario
respondieron_2024["PP3F_TOT"] = pd.to_numeric(respondieron_2024["PP3F_TOT"], errors="coerce")
respondieron_2024["PP3E_TOT"] = pd.to_numeric(respondieron_2024["PP3E_TOT"], errors="coerce")
respondieron_2024["P47T"] = pd.to_numeric(respondieron_2024["P47T"], errors="coerce")
respondieron_2024["edad"] = pd.to_numeric(respondieron_2024["edad"], errors="coerce")
respondieron_2024["sexo"] = pd.to_numeric(respondieron_2024["sexo"], errors="coerce")
respondieron_2024["nivel_educativo"] = respondieron_2024["nivel_educativo"].astype("category")
respondieron_2024["region"] = respondieron_2024["region"].astype("category")

# %%
# Crear variables necesarias
respondieron_2024 = respondieron_2024.copy()
respondieron_2024["salario_semanal"] = respondieron_2024["P47T"] / 4  # Aproxima salario semanal
respondieron_2024["edad"] = respondieron_2024["edad"].astype(int)
respondieron_2024["edad2"] = respondieron_2024["edad"] ** 2
respondieron_2024["mujer"] = (respondieron_2024["sexo"] == 2).astype(int)
respondieron_2024["HORASTRAB"] = respondieron_2024["PP3E_TOT"].fillna(0) + respondieron_2024["PP3F_TOT"].fillna(0)

# %%
# Crear dummies de nivel educativo y region
educ_dummies = pd.get_dummies(respondieron_2024["nivel_educativo"], prefix="educ", drop_first=True)
region_dummies = pd.get_dummies(respondieron_2024["region"], prefix="region", drop_first=True)

# %%
base = respondieron_2024[["salario_semanal", "edad", "edad2", "mujer", "HORASTRAB"]]

# %%
model = pd.concat([base, educ_dummies, region_dummies], axis=1)

# %%
# Separar entrenamiento y testeo
train_df, test_df = train_test_split(model, test_size=0.3, random_state=42)

# %%
def ajustar_modelo(vars_x, train_df):
    X = train_df[vars_x].astype(float)
    X = sm.add_constant(X)  # agregar constante
    Y = train_df["salario_semanal"].astype(float)
    model = sm.OLS(Y, X).fit()
    return model

# %%
# Definir las variables de cada modelo
variables_modelo = {
    "Modelo 1": ["edad"],
    "Modelo 2": ["edad", "edad2"],
    "Modelo 3": ["edad", "edad2"] + list(educ_dummies.columns),
    "Modelo 4": ["edad", "edad2"] + list(educ_dummies.columns) + ["mujer"],
    "Modelo 5": ["edad", "edad2"] + list(educ_dummies.columns) + ["mujer", "HORASTRAB"] + list(region_dummies.columns),
}

# %%
# Ajustar los modelos
modelos = {nombre: ajustar_modelo(vars_x, train_df) for nombre, vars_x in variables_modelo.items()}
modelos_resumen = {k: v.summary() for k, v in modelos.items()}
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1967: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
#Mostrar resumen del modelo mas completo
modelos_resumen["Modelo 5"]
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        salario_semanal   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     163.2
# Date:                Tue, 03 Jun 2025   Prob (F-statistic):          5.28e-254
# Time:                        10:34:33   Log-Likelihood:                -38718.
# No. Observations:                3154   AIC:                         7.746e+04
# Df Residuals:                    3144   BIC:                         7.752e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.152e+04   3625.106     -3.177      0.002   -1.86e+04   -4409.457
# edad        1289.4905    245.290      5.257      0.000     808.545    1770.436
# edad2         -5.8181      2.706     -2.150      0.032     -11.124      -0.512
# educ_2     -6595.0335   4382.486     -1.505      0.132   -1.52e+04    1997.789
# educ_3     -7241.9767   3407.588     -2.125      0.034   -1.39e+04    -560.656
# educ_4      3341.1179   3873.092      0.863      0.388   -4252.926    1.09e+04
# educ_5      8108.5477   4114.968      1.971      0.049      40.252    1.62e+04
# educ_6      3.485e+04   4277.246      8.148      0.000    2.65e+04    4.32e+04
# educ_7      7522.5219   4727.102      1.591      0.112   -1745.995    1.68e+04
# mujer               0          0        nan        nan           0           0
# HORASTRAB    943.0528     50.952     18.509      0.000     843.150    1042.955
# ==============================================================================
# Omnibus:                     3704.714   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1045869.318
# Skew:                           5.736   Prob(JB):                         0.00
# Kurtosis:                      91.469   Cond. No.                     3.86e+22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.48e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# lo haceos de notra manera yq eu observamos que en mujer figura nan por lo que debemos de estar cometineod un error.
# Aseguramos que salario_semanal esté en la base
train_data = respondieron_2024.copy()

# Creamos las variables necesarias
train_data["edad2"] = train_data["edad"]**2
train_data["educ"] = train_data["nivel_educativo"]
train_data["mujer"] = (train_data["sexo"] == 2).astype(int)

# Usamos dos variables adicionales limpias: salario_semanal y REGION (dummies)
region_dummies = pd.get_dummies(respondieron_2024["region"], prefix="region", drop_first=True)

# Variables independientes para cada modelo
X1 = train_data[["edad"]]
X2 = train_data[["edad", "edad2"]]
X3 = train_data[["edad", "edad2", "educ"]]
X4 = train_data[["edad", "edad2", "educ", "mujer"]]
X5 = train_data[["edad", "edad2", "educ", "mujer", "salario_semanal", "region"]]

y = train_data["salario_semanal"]

from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

def fit_model(X, y):
    X_const = sm.add_constant(X)
    model = sm.OLS(y, X_const).fit()
    return model

models = [fit_model(X, y) for X in [X1, X2, X3, X4, X5]]
for i, m in enumerate(models):
    print(f"Modelo {i+1}:\nResumen:\n{m.summary()}\n")
# Out:
# Modelo 1:
# Resumen:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        salario_semanal   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     638.3
# Date:                Tue, 03 Jun 2025   Prob (F-statistic):          7.94e-132
# Time:                        11:12:27   Log-Likelihood:                -56011.
# No. Observations:                4507   AIC:                         1.120e+05
# Df Residuals:                    4505   BIC:                         1.120e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7230.1242   1695.670      4.264      0.000    3905.778    1.06e+04
# edad         999.1660     39.548     25.265      0.000     921.633    1076.699
# ==============================================================================
# Omnibus:                     4977.075   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           844661.873
# Skew:                           5.346   Prob(JB):                         0.00
# Kurtosis:                      69.208   Cond. No.                         80.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Modelo 2:
# Resumen:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        salario_semanal   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     506.9
# Date:                Tue, 03 Jun 2025   Prob (F-statistic):          2.90e-199
# Time:                        11:12:27   Log-Likelihood:                -55853.
# No. Observations:                4507   AIC:                         1.117e+05
# Df Residuals:                    4504   BIC:                         1.117e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.603e+04   2458.163    -10.588      0.000   -3.08e+04   -2.12e+04
# edad        3458.2246    140.860     24.551      0.000    3182.069    3734.380
# edad2        -30.5200      1.683    -18.136      0.000     -33.819     -27.221
# ==============================================================================
# Omnibus:                     5090.978   Durbin-Watson:                   1.755
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1012919.164
# Skew:                           5.509   Prob(JB):                         0.00
# Kurtosis:                      75.612   Cond. No.                     7.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Modelo 3:
# Resumen:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        salario_semanal   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.215
# Method:                 Least Squares   F-statistic:                     413.1
# Date:                Tue, 03 Jun 2025   Prob (F-statistic):          4.51e-237
# Time:                        11:12:27   Log-Likelihood:                -55762.
# No. Observations:                4507   AIC:                         1.115e+05
# Df Residuals:                    4503   BIC:                         1.116e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.874e+04   2933.250    -16.617      0.000   -5.45e+04    -4.3e+04
# edad        3311.1008    138.501     23.907      0.000    3039.571    3582.631
# edad2        -28.4596      1.657    -17.180      0.000     -31.707     -25.212
# educ        6591.7452    485.392     13.580      0.000    5640.139    7543.351
# ==============================================================================
# Omnibus:                     5066.573   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1052597.059
# Skew:                           5.442   Prob(JB):                         0.00
# Kurtosis:                      77.072   Cond. No.                     9.16e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Modelo 4:
# Resumen:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        salario_semanal   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.215
# Method:                 Least Squares   F-statistic:                     413.1
# Date:                Tue, 03 Jun 2025   Prob (F-statistic):          4.51e-237
# Time:                        11:12:27   Log-Likelihood:                -55762.
# No. Observations:                4507   AIC:                         1.115e+05
# Df Residuals:                    4503   BIC:                         1.116e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.874e+04   2933.250    -16.617      0.000   -5.45e+04    -4.3e+04
# edad        3311.1008    138.501     23.907      0.000    3039.571    3582.631
# edad2        -28.4596      1.657    -17.180      0.000     -31.707     -25.212
# educ        6591.7452    485.392     13.580      0.000    5640.139    7543.351
# mujer               0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                     5066.573   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1052597.059
# Skew:                           5.442   Prob(JB):                         0.00
# Kurtosis:                      77.072   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Modelo 5:
# Resumen:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        salario_semanal   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.766e+32
# Date:                Tue, 03 Jun 2025   Prob (F-statistic):               0.00
# Time:                        11:12:27   Log-Likelihood:                 96193.
# No. Observations:                4507   AIC:                        -1.924e+05
# Df Residuals:                    4502   BIC:                        -1.923e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const           -4.063e-14    3.9e-15    -10.417      0.000   -4.83e-14    -3.3e-14
# edad            -5.773e-12   3.35e-13    -17.234      0.000   -6.43e-12   -5.12e-12
# edad2            7.799e-14    3.9e-15     20.019      0.000    7.04e-14    8.56e-14
# educ              1.56e-11   1.13e-12     13.829      0.000    1.34e-11    1.78e-11
# mujer            8.529e-22   1.61e-28   5.29e+06      0.000    8.53e-22    8.53e-22
# salario_semanal     1.0000    3.4e-17   2.95e+16      0.000       1.000       1.000
# region          -1.815e-12   1.64e-13    -11.081      0.000   -2.14e-12   -1.49e-12
# ==============================================================================
# Omnibus:                      726.519   Durbin-Watson:                   0.431
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7946.438
# Skew:                           0.420   Prob(JB):                         0.00
# Kurtosis:                       9.451   Cond. No.                     3.97e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.73e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1967: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])

# %%
print(train_data.columns.tolist())
# Out:
# ['sexo', 'edad', 'nivel_educativo', 'region', 'pondera', 'P47T', 'PP3E_TOT', 'PP3F_TOT', 'salario_semanal', 'edad2', 'mujer', 'HORASTRAB']

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import statsmodels.api as sm
# CORREGIMOS LOS ERRORES PARA LA TABLA3  QUE salario_semanal ES MI VARIABLE DEPENDIENTE, no debe ir en X.
# REGION DEBE CONVERTIRSE EN dummies (columnas numéricas), no usarse directamente como texto.
# Variables adicionales bien hechas
region_dummies_train = pd.get_dummies(train_data["region"], prefix="region", drop_first=True)

X5 = pd.concat([
    train_data[["edad", "edad2", "educ", "mujer"]],
    region_dummies_train
], axis=1)

X_list = [X1, X2, X3, X4, X5]

# Reentrenar los modelos
models = [fit_model(X, y) for X in X_list]

# %%
# Tabla 3: Métricas de evaluación en test
# Construcción de test
region_dummies = pd.get_dummies(test_data["region"], prefix="region", drop_first=True)
X_test_5 = pd.concat([
    test_data[["edad", "edad2", "educ", "mujer"]],
    region_dummies
], axis=1)

X_test_list = [X_test_1, X_test_2, X_test_3, X_test_4, X_test_5]

metricas = {}

for i, model in enumerate(models):
    X_test_i = sm.add_constant(X_test_list[i], has_constant='add')
    X_test_i = X_test_i[model.model.exog_names]  # alineamos columnas

    y_pred = model.predict(X_test_i)

    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)

    metricas[f"Modelo {i+1}"] = {
        "MSE test": round(mse, 2),
        "RMSE test": round(rmse, 2),
        "MAE test": round(mae, 2)
    }

tabla_metricas_df = pd.DataFrame(metricas).T
display(tabla_metricas_df)
# Out:
#               MSE test  RMSE test  MAE test
# Modelo 1  3.647946e+09   60398.23  37298.19
# Modelo 2  3.399666e+09   58306.65  35085.35
# Modelo 3  3.265908e+09   57148.12  34487.36
# Modelo 4  3.265908e+09   57148.12  34487.36
# Modelo 5  3.265908e+09   57148.12  34487.36
